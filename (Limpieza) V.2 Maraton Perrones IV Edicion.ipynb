# %%
import numpy as np
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/Maraton de los Perrones IV Edición/INSCRIPCIONES/Primera revisión de limpieza, maratón perrones iv edicion.xlsx'
data = pd.read_excel(path)
data.head(10)
# Out:
#                                Nombre Edad     Fecha Nacimiento  \
# 0  Yineth Estefanía Lizárraga Vázquez   23  1999-12-27 00:00:00
# 1    Marco Antonio Buenrostro Camargo   32  1990-09-14 00:00:00
# 2                       Tirso Miranda  NaN                  NaN
# 3        Carlos Enrique Soto González   54  1969-06-16 00:00:00
# 4          Eleodoro González González   68  1955-02-11 00:00:00
# 5                  Anahí Solís Larios   33  1990-06-05 00:00:00
# 6             Norah Navarro Contreras   34  1989-04-25 00:00:00
# 7       María Fernanda Borbón Córdova   33  1990-01-13 00:00:00
# 8        Benny Lester Márquez Higuera   22  2001-02-27 00:00:00
# 9          Miguel Alonso Martínez Mar   35  1988-04-03 00:00:00
#
#           Celular Lugar de Residencia Talla    L   XL  XXL    S    M  L.1 XL.1
# 0  66 24 49 32 01                 NaN     M  NaN  NaN  NaN  NaN    1  NaN  NaN
# 1    662 182 0356                 NaN     M  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...

# %%
data = data.iloc[:153, :6]
data.head(10)
# Out:
#                                Nombre Edad     Fecha Nacimiento  \
# 0  Yineth Estefanía Lizárraga Vázquez   23  1999-12-27 00:00:00
# 1    Marco Antonio Buenrostro Camargo   32  1990-09-14 00:00:00
# 2                       Tirso Miranda  NaN                  NaN
# 3        Carlos Enrique Soto González   54  1969-06-16 00:00:00
# 4          Eleodoro González González   68  1955-02-11 00:00:00
# 5                  Anahí Solís Larios   33  1990-06-05 00:00:00
# 6             Norah Navarro Contreras   34  1989-04-25 00:00:00
# 7       María Fernanda Borbón Córdova   33  1990-01-13 00:00:00
# 8        Benny Lester Márquez Higuera   22  2001-02-27 00:00:00
# 9          Miguel Alonso Martínez Mar   35  1988-04-03 00:00:00
#
#           Celular Lugar de Residencia Talla
# 0  66 24 49 32 01                 NaN     M
# 1    662 182 0356                 NaN     M
# 2             NaN                 NaN     M
# 3    662 187 1313                 NaN     G
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Nombre               151 non-null    object
#  1   Edad                 140 non-null    object
#  2   Fecha Nacimiento     113 non-null    object
#  3   Celular              120 non-null    object
#  4   Lugar de Residencia  129 non-null    object
#  5   Talla                145 non-null    object
# dtypes: object(6)
# memory usage: 7.3+ KB

# %%
data.isnull().sum()
# Out:
# Nombre                  2
# Edad                   13
# Fecha Nacimiento       40
# Celular                33
# Lugar de Residencia    24
# Talla                   8
# dtype: int64

# %%
data_recortado = data.drop(['Fecha Nacimiento', 'Celular'], axis=1)
data_recortado
# Out:
#                                  Nombre Edad Lugar de Residencia Talla
# 0    Yineth Estefanía Lizárraga Vázquez   23                 NaN     M
# 1      Marco Antonio Buenrostro Camargo   32                 NaN     M
# 2                         Tirso Miranda  NaN                 NaN     M
# 3          Carlos Enrique Soto González   54                 NaN     G
# 4            Eleodoro González González   68                 NaN     M
# ..                                  ...  ...                 ...   ...
# 148                Carla Baneza Ramírez   45  Hermosillo, Sonora     M
# 149           José María Guereña Moreno   45  Hermosillo, Sonora   NaN
# 150     Héctor Antonio Bustamante Ozuna   36  Hermosillo, Sonora   NaN
# 151                Mauro Sotelo Salgado   46                 NaN   NaN
# 152           Juan Antonio Rivera Valle   30     Nogales, Sonora   NaN
#
# [153 rows x 4 columns]

# %%
dataSinSTAFF = data[data['Edad']!='STAFF']
dataSinSTAFF
# Out:
#                                  Nombre Edad     Fecha Nacimiento  \
# 0    Yineth Estefanía Lizárraga Vázquez   23  1999-12-27 00:00:00
# 1      Marco Antonio Buenrostro Camargo   32  1990-09-14 00:00:00
# 2                         Tirso Miranda  NaN                  NaN
# 3          Carlos Enrique Soto González   54  1969-06-16 00:00:00
# 4            Eleodoro González González   68  1955-02-11 00:00:00
# ..                                  ...  ...                  ...
# 148                Carla Baneza Ramírez   45  1978-09-17 00:00:00
# 149           José María Guereña Moreno   45  1978-01-11 00:00:00
# 150     Héctor Antonio Bustamante Ozuna   36                  NaN
# 151                Mauro Sotelo Salgado   46  1977-01-25 00:00:00
# 152           Juan Antonio Rivera Valle   30  1993-02-26 00:00:00
#
#             Celular Lugar de Residencia Talla
# 0    66 24 49 32 01                 NaN     M
# 1      662 182 0356                 NaN     M
# ...

# %%
path2Save = '/content/drive/MyDrive/Maraton de los Perrones IV Edición/INSCRIPCIONES/Medio Maraton Analisis/Segunda revisión de limpieza, med. maratón perrones iv edicion.xlsx'
dataSinSTAFF.to_excel(path2Save, index = False)
