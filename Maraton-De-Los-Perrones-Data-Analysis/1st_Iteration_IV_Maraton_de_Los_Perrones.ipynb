# %%
# Get the data from the Github repository.
# !git clone https://github.com/IvanSotomyor/Data-Analysis-Maraton-de-los-Perrones-IV.git
# Out:
# Cloning into 'Data-Analysis-Maraton-de-los-Perrones-IV'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 29 (delta 10), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (29/29), 1.24 MiB | 10.64 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
#Show list
# !ls
# Out:
# Data-Analysis-Maraton-de-los-Perrones-IV  sample_data

# %%
# In case there is need to erase a folder.
# !rm -rf Data-Analysis-Maraton-de-los-Perrones-IV

# %%
# Import Libraries.
import numpy as np
import pandas as pd

# %% [markdown]
# <h2>21 km Cleaning</h2>
#
# ---

# %%
# Upload the excel file
path = '/content/Data-Analysis-Maraton-de-los-Perrones-IV/INSCRITOS IV Edición  MARATON PERRONES.xlsx'

# Specify sheet
df = pd.read_excel(path, 'MEDIO MARATON ')
print(df)
# Out:
#      Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0           NaN                                                NaN        NaN
# 1           NaN                                                NaN        NaN
# 2           NaN                                                NaN        NaN
# 3           NaN                                                NaN        NaN
# 4           NaN  INSCRITOS AL IV MEDIO MARATON INTERNACIONAL DE...        NaN
# ..          ...                                                ...        ...
# 167         NaN                                                NaN        NaN
# 168         NaN                                                NaN        NaN
# 169         NaN                                                NaN        NaN
# 170         NaN                                                NaN        NaN
# 171         NaN                                                NaN        NaN
#
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0         NaN                                                NaN        NaN
# 1         NaN                                                NaN        NaN
# 2         NaN                                                NaN        NaN
# 3         NaN                                                NaN        NaN
# 4         NaN  INSCRITOS AL IV MEDIO MARATON INTERNACIONAL DE...        NaN
# 5         NaN                                                NaN        NaN
# 6         NaN                                                NaN        BIB
# 7         NaN                                                NaN        NaN
# 8         1.0                                                ).-        101
# 9         2.0                                                ).-        102
#
#                            Unnamed: 3 Unnamed: 4           Unnamed: 5  \
# ...

# %%
# Delete the 7 empty rows in the begining of the df.
df_cut = df.iloc[8:, :10]
df_cut
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2                          Unnamed: 3  \
# 8           1.0        ).-        101  Yineth Estefanía Lizárraga Vázquez
# 9           2.0        ).-        102    Marco Antonio Buenrostro Camargo
# 10          3.0        ).-        103                       Tirso Miranda
# 11          4.0        ).-        104        Carlos Enrique Soto González
# 12          5.0        ).-        105          Eleodoro González González
# ..          ...        ...        ...                                 ...
# 167         NaN        NaN        NaN                                 NaN
# 168         NaN        NaN        NaN                                 NaN
# 169         NaN        NaN        NaN                                 NaN
# 170         NaN        NaN        NaN                                 NaN
# 171         NaN        NaN        NaN                                 NaN
#
#     Unnamed: 4           Unnamed: 5           Unnamed: 6 Unnamed: 7  \
# ...

# %%
# Remove unnecesary info
df_cut2 = df_cut.drop('Unnamed: 0', axis=1)
df_cut2 = df_cut2.drop('Unnamed: 1', axis=1)
df_cut2 = df_cut2.drop('Unnamed: 5', axis=1)
df_cut2 = df_cut2.drop('Unnamed: 6', axis=1)
df_cut2
# Out:
#     Unnamed: 2                          Unnamed: 3 Unnamed: 4 Unnamed: 7  \
# 8          101  Yineth Estefanía Lizárraga Vázquez         23        NaN
# 9          102    Marco Antonio Buenrostro Camargo         32        NaN
# 10         103                       Tirso Miranda        NaN        NaN
# 11         104        Carlos Enrique Soto González         54        NaN
# 12         105          Eleodoro González González         68        NaN
# ..         ...                                 ...        ...        ...
# 167        NaN                                 NaN        NaN        NaN
# 168        NaN                                 NaN        NaN        NaN
# 169        NaN                                 NaN        NaN        NaN
# 170        NaN                                 NaN        NaN        NaN
# 171        NaN                                 NaN        NaN        NaN
#
#       Unnamed: 8 Unnamed: 9
# 8              M          F
# 9              M          M
# ...

# %%
# Assign new column names
column_names = ['BIB', 'Nombre', 'Edad', 'Lugar de Residencia', 'Talla', 'Genero']

# %%
# Remove empty spaces at the end of the df
df_midMthon = df_cut2.iloc[:157, :]

# Apply new column names
df_midMthon = df_midMthon.rename(columns=dict(zip(df_midMthon.columns, column_names)))
df_midMthon
# Out:
#      BIB                              Nombre Edad Lugar de Residencia Talla  \
# 8    101  Yineth Estefanía Lizárraga Vázquez   23                 NaN     M
# 9    102    Marco Antonio Buenrostro Camargo   32                 NaN     M
# 10   103                       Tirso Miranda  NaN                 NaN     M
# 11   104        Carlos Enrique Soto González   54                 NaN     G
# 12   105          Eleodoro González González   68                 NaN     M
# ..   ...                                 ...  ...                 ...   ...
# 160  253           Juan Antonio Rivera Valle   30     Nogales, Sonora   NaN
# 161  254             Eva Ruth Corrales Alday  NaN  Hermosillo, Sonora     M
# 162  255    Gabriel Humberto Murrieta Osorio   61  Hermosillo, Sonora     M
# 163  256         Luis Enrique Zavala Pacheco   54                 NaN   NaN
# 164  257   Gaston Paulino Castillo Hernandez   65                 NaN   NaN
#
#     Genero
# 8        F
# 9        M
# 10       M
# ...

# %%
# General info
df_midMthon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 8 to 164
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   BIB                  157 non-null    object
#  1   Nombre               157 non-null    object
#  2   Edad                 144 non-null    object
#  3   Lugar de Residencia  132 non-null    object
#  4   Talla                148 non-null    object
#  5   Genero               157 non-null    object
# dtypes: object(6)
# memory usage: 7.5+ KB

# %%
# See if there is any empty row.
df_midMthon.isnull().sum()
# Out:
# BIB                     0
# Nombre                  0
# Edad                   13
# Lugar de Residencia    25
# Talla                   9
# Genero                  0
# dtype: int64

# %%
# Calculate how many STAFF members are in the event
count_staff = (df_midMthon.loc[:, 'Edad'].str.contains('STAFF')).sum()

print("Número de integrantes STAFF para el evento:", count_staff)
# Out:
# Número de integrantes STAFF para el evento: 25

# %%
# Remove STAFF members from dataframe
df_midMthon2 = df_midMthon[df_midMthon['Edad']!='STAFF']
df_midMthon2

#This leaves with 132 participants in the 1/2 marathon.
# Out:
#      BIB                              Nombre Edad Lugar de Residencia Talla  \
# 8    101  Yineth Estefanía Lizárraga Vázquez   23                 NaN     M
# 9    102    Marco Antonio Buenrostro Camargo   32                 NaN     M
# 10   103                       Tirso Miranda  NaN                 NaN     M
# 11   104        Carlos Enrique Soto González   54                 NaN     G
# 12   105          Eleodoro González González   68                 NaN     M
# ..   ...                                 ...  ...                 ...   ...
# 160  253           Juan Antonio Rivera Valle   30     Nogales, Sonora   NaN
# 161  254             Eva Ruth Corrales Alday  NaN  Hermosillo, Sonora     M
# 162  255    Gabriel Humberto Murrieta Osorio   61  Hermosillo, Sonora     M
# 163  256         Luis Enrique Zavala Pacheco   54                 NaN   NaN
# 164  257   Gaston Paulino Castillo Hernandez   65                 NaN   NaN
#
#     Genero
# 8        F
# 9        M
# 10       M
# ...

# %%
# Add a classification column named "Maraton", where the value is going to be 0 if the runners took the 21 km route, and 1 if the runners took the 42 km route.
df_midMthon2['Maraton'] = 0
df_midMthon2
# Out:
# <ipython-input-69-b2ad12cbaf6b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_midMthon2['Maraton'] = 0
#      BIB                              Nombre Edad Lugar de Residencia Talla  \
# 8    101  Yineth Estefanía Lizárraga Vázquez   23                 NaN     M
# 9    102    Marco Antonio Buenrostro Camargo   32                 NaN     M
# 10   103                       Tirso Miranda  NaN                 NaN     M
# 11   104        Carlos Enrique Soto González   54                 NaN     G
# 12   105          Eleodoro González González   68                 NaN     M
# ..   ...                                 ...  ...                 ...   ...
# 160  253           Juan Antonio Rivera Valle   30     Nogales, Sonora   NaN
# ...

# %% [markdown]
# <h2>42 km cleaning</h2>
#
# ---

# %%
# Read specified sheet
df42 = pd.read_excel(path, 'MARATON')
df42.head(10)
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0         NaN                                                NaN        NaN
# 1         NaN  INSCRITOS AL IV MARATON INTERNACIONAL DE LOS P...        NaN
# 2         NaN                                                NaN        NaN
# 3         NaN                               11 de Agosto de 2023        NaN
# 4         NaN                                                NaN        NaN
# 5         NaN                                                NaN        BIB
# 6         NaN                                                NaN        NaN
# 7         1.0                                                ).-         93
# 8         2.0                                                ).-        322
# 9         3.0                                                ).-          1
#
#                     x                       Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# ...

# %%
# Delete the empty rows in the begining of the df.
df_cut42 = df42.iloc[7:, :14]
df_cut42
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2                   x  \
# 7          1.0        ).-         93                 NaN
# 8          2.0        ).-        322                 NaN
# 9          3.0        ).-          1  se cambió al medio
# 10         4.0        ).-          2                 NaN
# 11         5.0        ).-          3                 NaN
# ..         ...        ...        ...                 ...
# 74         NaN        NaN        NaN                 NaN
# 75         NaN        NaN        NaN                 NaN
# 76         NaN        NaN        NaN                 NaN
# 77         NaN        NaN        NaN                 NaN
# 78         NaN        NaN        NaN                 NaN
#
#                          Unnamed: 4 Unnamed: 5      Unnamed: 6 Unnamed: 7  \
# 7             Tamar Rodríguez Colom       CDMX               M          M
# 8            Jesús Sanchez Casillas        NaN               M          M
# ...

# %%
# Remove unnecesary columns
dropped_columns = ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 5', 'Unnamed: 8', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12']
df_cut42 = df_cut42.drop(dropped_columns, axis=1)
df_cut42
# Out:
#    Unnamed: 2                   x                       Unnamed: 4  \
# 7          93                 NaN            Tamar Rodríguez Colom
# 8         322                 NaN           Jesús Sanchez Casillas
# 9           1  se cambió al medio  Luz Angélica Palomares (Piolín)
# 10          2                 NaN             Manuel Cruz Grijalva
# 11          3                 NaN         Aracely Esteban Elizalde
# ..        ...                 ...                              ...
# 74        NaN                 NaN                              NaN
# 75        NaN                 NaN                              NaN
# 76        NaN                 NaN                              NaN
# 77        NaN                 NaN                              NaN
# 78        NaN                 NaN       AGUA EN BOLIS PARA CARRERA
#
#         Unnamed: 6 Unnamed: 7 Unnamed: 9            Unnamed: 13
# 7                M          M        NaN                   CDMX
# ...

# %%
# Change column order to match the 21 km dataframe for future merge
column_order = [0, 2, 5, 6, 4, 3, 1]
df_cut42_ordered = df_cut42[df_cut42.columns[column_order]]
df_cut42_ordered.head(10)
# Out:
#    Unnamed: 2                       Unnamed: 4 Unnamed: 9  \
# 7          93            Tamar Rodríguez Colom        NaN
# 8         322           Jesús Sanchez Casillas        NaN
# 9           1  Luz Angélica Palomares (Piolín)         50
# 10          2             Manuel Cruz Grijalva         35
# 11          3         Aracely Esteban Elizalde         33
# 12          4      Jesús Manuel Zavala Pacheco        NaN
# 13          5         Ricardo Candiani Porchas         59
# 14          6               José Salas Mendoza         60
# 15          7    Ericka Yamineth Santiago León        NaN
# 16          8          Luis Javier Gómez Rocha         59
#
#               Unnamed: 13 Unnamed: 7 Unnamed: 6                   x
# 7                    CDMX          M          M                 NaN
# 8   San Luis Río Colorado          M          M                 NaN
# 9     Agua Prieta, Sonora          L          F  se cambió al medio
# ...

# %%
# Assign new column names
column_names42 = ['BIB', 'Nombre', 'Edad', 'Lugar de Residencia', 'Talla', 'Genero', 'Cambios']
df_mthon = df_cut42_ordered.rename(columns=dict(zip(df_cut42_ordered.columns, column_names42)))
df_mthon
# Out:
#     BIB                           Nombre    Edad    Lugar de Residencia Talla  \
# 7    93            Tamar Rodríguez Colom     NaN                   CDMX     M
# 8   322           Jesús Sanchez Casillas     NaN  San Luis Río Colorado     M
# 9     1  Luz Angélica Palomares (Piolín)      50    Agua Prieta, Sonora     L
# 10    2             Manuel Cruz Grijalva      35             Hermosillo     L
# 11    3         Aracely Esteban Elizalde      33             Hermosillo     M
# ..  ...                              ...     ...                    ...   ...
# 74  NaN                              NaN  QUEDAN                    NaN   NaN
# 75  NaN                              NaN     NaN                    NaN   NaN
# 76  NaN                              NaN     NaN                    NaN   NaN
# 77  NaN                              NaN     NaN                    NaN   NaN
# 78  NaN       AGUA EN BOLIS PARA CARRERA     NaN                    NaN   NaN
#
# ...

# %%
#Remove empty rows at the end of the dataframe
df_mthon = df_mthon.iloc[:58, :]
df_mthon
# Out:
#     BIB                              Nombre Edad    Lugar de Residencia Talla  \
# 7    93               Tamar Rodríguez Colom  NaN                   CDMX     M
# 8   322              Jesús Sanchez Casillas  NaN  San Luis Río Colorado     M
# 9     1     Luz Angélica Palomares (Piolín)   50    Agua Prieta, Sonora     L
# 10    2                Manuel Cruz Grijalva   35             Hermosillo     L
# 11    3            Aracely Esteban Elizalde   33             Hermosillo     M
# 12    4         Jesús Manuel Zavala Pacheco  NaN     San Diego, CA. USA     M
# 13    5            Ricardo Candiani Porchas   59             Hermosillo     M
# 14    6                  José Salas Mendoza   60             Hermosillo     M
# 15    7       Ericka Yamineth Santiago León  NaN             Hermosillo     M
# 16    8             Luis Javier Gómez Rocha   59             Hermosillo     M
# 17    9              Octavio Servin Alameda   65              Bacobampo     M
# ...

# %%
# Add the classification column used in the 21 km category. Since this is the 42 km category, the value assigned will be 1
df_mthon['Maraton'] = 1
df_mthon
# Out:
# <ipython-input-76-10bec6fdfac0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mthon['Maraton'] = 1
#     BIB                              Nombre Edad    Lugar de Residencia Talla  \
# 7    93               Tamar Rodríguez Colom  NaN                   CDMX     M
# 8   322              Jesús Sanchez Casillas  NaN  San Luis Río Colorado     M
# 9     1     Luz Angélica Palomares (Piolín)   50    Agua Prieta, Sonora     L
# 10    2                Manuel Cruz Grijalva   35             Hermosillo     L
# 11    3            Aracely Esteban Elizalde   33             Hermosillo     M
# 12    4         Jesús Manuel Zavala Pacheco  NaN     San Diego, CA. USA     M
# ...

# %%
# In the column 'Cambios' there are some runners who made a change of category, so there has to be a reassignment for these cases.
df_mthon.loc[df_mthon['Cambios'] == 'se cambió al medio', 'Maraton'] = 0
df_mthon
# Out:
#     BIB                              Nombre Edad    Lugar de Residencia Talla  \
# 7    93               Tamar Rodríguez Colom  NaN                   CDMX     M
# 8   322              Jesús Sanchez Casillas  NaN  San Luis Río Colorado     M
# 9     1     Luz Angélica Palomares (Piolín)   50    Agua Prieta, Sonora     L
# 10    2                Manuel Cruz Grijalva   35             Hermosillo     L
# 11    3            Aracely Esteban Elizalde   33             Hermosillo     M
# 12    4         Jesús Manuel Zavala Pacheco  NaN     San Diego, CA. USA     M
# 13    5            Ricardo Candiani Porchas   59             Hermosillo     M
# 14    6                  José Salas Mendoza   60             Hermosillo     M
# 15    7       Ericka Yamineth Santiago León  NaN             Hermosillo     M
# 16    8             Luis Javier Gómez Rocha   59             Hermosillo     M
# 17    9              Octavio Servin Alameda   65              Bacobampo     M
# ...

# %%
# The column 'Cambios' is no longer needed, it can be dropped now.
df_mthon = df_mthon.drop('Cambios', axis=1)
df_mthon
# Out:
#     BIB                              Nombre Edad    Lugar de Residencia Talla  \
# 7    93               Tamar Rodríguez Colom  NaN                   CDMX     M
# 8   322              Jesús Sanchez Casillas  NaN  San Luis Río Colorado     M
# 9     1     Luz Angélica Palomares (Piolín)   50    Agua Prieta, Sonora     L
# 10    2                Manuel Cruz Grijalva   35             Hermosillo     L
# 11    3            Aracely Esteban Elizalde   33             Hermosillo     M
# 12    4         Jesús Manuel Zavala Pacheco  NaN     San Diego, CA. USA     M
# 13    5            Ricardo Candiani Porchas   59             Hermosillo     M
# 14    6                  José Salas Mendoza   60             Hermosillo     M
# 15    7       Ericka Yamineth Santiago León  NaN             Hermosillo     M
# 16    8             Luis Javier Gómez Rocha   59             Hermosillo     M
# 17    9              Octavio Servin Alameda   65              Bacobampo     M
# ...

# %% [markdown]
# <h2>Time to merge tables</h2>

# %%
# Merge both categories in a single dataframe
mthonmerged = pd.merge(df_midMthon2, df_mthon, how='outer')
mthonmerged.head(200)
# Out:
# <ipython-input-79-475793026713>:2: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   mthonmerged = pd.merge(df_midMthon2, df_mthon, how='outer')
# <ipython-input-79-475793026713>:2: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   mthonmerged = pd.merge(df_midMthon2, df_mthon, how='outer')
#        BIB                              Nombre  Edad Lugar de Residencia  \
# 0    101.0  Yineth Estefanía Lizárraga Vázquez  23.0                 NaN
# 1    102.0    Marco Antonio Buenrostro Camargo  32.0                 NaN
# 2    103.0                       Tirso Miranda   NaN                 NaN
# 3    104.0        Carlos Enrique Soto González  54.0                 NaN
# 4    105.0          Eleodoro González González  68.0                 NaN
# ...

# %% [markdown]
# <h2>Transformation</h2>

# %%
# Remove empty rows based on 'Nombre' column
mthonmerged = mthonmerged.dropna(subset=['Nombre'])
mthonmerged
# Out:
#        BIB                              Nombre  Edad Lugar de Residencia  \
# 0    101.0  Yineth Estefanía Lizárraga Vázquez  23.0                 NaN
# 1    102.0    Marco Antonio Buenrostro Camargo  32.0                 NaN
# 2    103.0                       Tirso Miranda   NaN                 NaN
# 3    104.0        Carlos Enrique Soto González  54.0                 NaN
# 4    105.0          Eleodoro González González  68.0                 NaN
# ..     ...                                 ...   ...                 ...
# 184     49            Joel Ernesto Moreno Soto    48  Hermosillo, Sonora
# 185     50     Luis Fernando González Gastelum    38  Hermosillo, Sonora
# 187     52                    Kristina Morales   NaN                 NaN
# 188     53                    Humberto Ramírez   NaN                 NaN
# 189     54     Juan Carlos Fernández (Chileno)   NaN                 NaN
#
#     Talla Genero  Maraton
# 0       M      F        0
# 1       M      M        0
# ...

# %%
# Check for remaining null values in each column
mthonmerged.isnull().sum()
# Out:
# BIB                     0
# Nombre                  0
# Edad                   20
# Lugar de Residencia    27
# Talla                  10
# Genero                  0
# Maraton                 0
# dtype: int64

# %%
# Analyze possible choices to fill 'Lugar de Residencia' column. In case there are duplicate choices of the same, transform them into one
mthonmerged['Lugar de Residencia'].unique()
# Out:
# array([nan, 'CDMX', 'Hillo., Son.', 'Hermosillo, Sonora',
#        'Cd. Obregón, Son', 'Guaymas, Sonora', 'Nogales, Sonora',
#        'Tijuana, B.C.', 'San Luis Río Colorado', 'Agua Prieta, Sonora',
#        'Hermosillo', 'San Diego, CA. USA', 'Bacobampo', 'Ensenada, B.C.',
#        'Phoenix, Az. USA', 'Culiacán, Sinaloa', 'Cananea, Sonora',
#        'Caborca, Sonora', 'Mexicali, B.C.', 'Villa Juarez, Sonora',
#        'Monterrery, N.L.', 'León, Gto.', 'Cuernavaca, Morelos'],
#       dtype=object)

# %%
mthonmerged.groupby("Lugar de Residencia").count()
# Out:
#                        BIB  Nombre  Edad  Talla  Genero  Maraton
# Lugar de Residencia
# Agua Prieta, Sonora      1       1     1      1       1        1
# Bacobampo                1       1     1      1       1        1
# CDMX                     2       2     1      2       2        2
# Caborca, Sonora          1       1     1      1       1        1
# Cananea, Sonora          1       1     1      1       1        1
# Cd. Obregón, Son         4       4     4      4       4        4
# Cuernavaca, Morelos      1       1     1      1       1        1
# Culiacán, Sinaloa        4       4     4      4       4        4
# Ensenada, B.C.           1       1     1      1       1        1
# Guaymas, Sonora          4       4     4      4       4        4
# Hermosillo              11      11    10     11      11       11
# Hermosillo, Sonora     111     111   104    107     111      111
# Hillo., Son.             6       6     6      6       6        6
# ...

# %%
# Merge similar fields into one. Also, remove the state of each city and make a separate column for them.
mthonmerged = mthonmerged.replace('Hermosillo, Sonora', 'Hermosillo')
mthonmerged = mthonmerged.replace('Hillo., Son.', 'Hermosillo')
mthonmerged = mthonmerged.replace('Caborca, Sonora', 'Caborca')
mthonmerged = mthonmerged.replace('Cananea, Sonora', 'Cananea')
mthonmerged = mthonmerged.replace('Cd. Obregón, Son', 'Cd. Obregón')
mthonmerged = mthonmerged.replace('Agua Prieta, Sonora', 'Agua Prieta')
mthonmerged = mthonmerged.replace('Cuernavaca, Morelos', 'Cuernavaca')
mthonmerged = mthonmerged.replace('Culiacán, Sinaloa', 'Culiacán')
mthonmerged = mthonmerged.replace('Ensenada, B.C.', 'Ensenada')
mthonmerged = mthonmerged.replace('Guaymas, Sonora', 'Guaymas')
mthonmerged = mthonmerged.replace('León, Gto.', 'León')
mthonmerged = mthonmerged.replace('Mexicali, B.C.', 'Mexicali')
mthonmerged = mthonmerged.replace('Monterrery, N.L.', 'Monterrey')
mthonmerged = mthonmerged.replace('Nogales, Sonora', 'Nogales')
mthonmerged = mthonmerged.replace('Phoenix, Az. USA', 'Phoenix')
mthonmerged = mthonmerged.replace('San Diego, CA. USA', 'San Diego')
mthonmerged = mthonmerged.replace('Tijuana, B.C.', 'Tijuana')
mthonmerged = mthonmerged.replace('Villa Juarez, Sonora', 'Villa Juarez')
mthonmerged = mthonmerged.replace('G', 'L')

# %%
mthonmerged.groupby("Lugar de Residencia").count()
# Out:
#                        BIB  Nombre  Edad  Talla  Genero  Maraton
# Lugar de Residencia
# Agua Prieta              1       1     1      1       1        1
# Bacobampo                1       1     1      1       1        1
# CDMX                     2       2     1      2       2        2
# Caborca                  1       1     1      1       1        1
# Cananea                  1       1     1      1       1        1
# Cd. Obregón              4       4     4      4       4        4
# Cuernavaca               1       1     1      1       1        1
# Culiacán                 4       4     4      4       4        4
# Ensenada                 1       1     1      1       1        1
# Guaymas                  4       4     4      4       4        4
# Hermosillo             128     128   120    124     128      128
# León                     1       1     1      1       1        1
# Mexicali                 1       1     1      1       1        1
# ...

# %%
# Title change to better match with the future 'Estado' column
mthonmerged = mthonmerged.rename(columns={'Lugar de Residencia': 'Ciudad'})
mthonmerged
# Out:
#        BIB                              Nombre  Edad      Ciudad Talla Genero  \
# 0    101.0  Yineth Estefanía Lizárraga Vázquez  23.0         NaN     M      F
# 1    102.0    Marco Antonio Buenrostro Camargo  32.0         NaN     M      M
# 2    103.0                       Tirso Miranda   NaN         NaN     M      M
# 3    104.0        Carlos Enrique Soto González  54.0         NaN     L      M
# 4    105.0          Eleodoro González González  68.0         NaN     M      M
# ..     ...                                 ...   ...         ...   ...    ...
# 184   49.0            Joel Ernesto Moreno Soto  48.0  Hermosillo     M      M
# 185   50.0     Luis Fernando González Gastelum  38.0  Hermosillo     S      M
# 187   52.0                    Kristina Morales   NaN         NaN     M      F
# 188   53.0                    Humberto Ramírez   NaN         NaN   XXL      M
# 189   54.0     Juan Carlos Fernández (Chileno)   NaN         NaN   NaN      M
#
#      Maraton
# 0          0
# ...

# %%
# Checkpoint to add future missing values
save_checkpoint = 'Datos_Limpios_Incompletos_Inscripciones_Maratones.xlsx'
mthonmerged.to_excel(save_checkpoint, index = False)

# %% [markdown]
# <h2>Fill empty values</h2>

# %%
mthonmerged.isnull().sum()
# Out:
# BIB         0
# Nombre      0
# Edad       20
# Ciudad     27
# Talla      10
# Genero      0
# Maraton     0
# dtype: int64

# %%
# Calculate the mode of the column 'Ciudad'
moda_ciudad = mthonmerged['Ciudad'].mode()
moda_ciudad[0]
# Out:
# 'Hermosillo'

# %%
# Fill empty fields with the mode
mthonmerged['Ciudad'].fillna(moda_ciudad[0], inplace = True)

# %%
# Same proccess with column 'Talla'
moda_talla = mthonmerged['Talla'].mode()
moda_talla[0]
# Out:
# 'M'

# %%
mthonmerged['Talla'].fillna(moda_talla[0], inplace = True)

# %%
# For 'Edad' column, do mean instead of mode
mean_edad = round(mthonmerged['Edad'].mean())
mthonmerged['Edad'].fillna(mean_edad, inplace = True)

# %%
# Make sure there are no more empty fields
mthonmerged.isnull().sum()
# Out:
# BIB        0
# Nombre     0
# Edad       0
# Ciudad     0
# Talla      0
# Genero     0
# Maraton    0
# dtype: int64

# %%
# Function to assign a State to each city
def assign_state(City):
    if City in ['Agua Prieta', 'Bacobampo', 'Cananea', 'Cd. Obregón', 'Guaymas', 'Hermosillo', 'Nogales', 'Caborca', 'San Luis Río Colorado', 'Villa Juarez']:
        return 'Sonora'
    elif City in ['Ensenada', 'Mexicali', 'Tijuana']:
        return 'Baja California'
    elif City == 'Phoenix':
        return 'Arizona, USA'
    elif City == 'San Diego':
        return 'California, USA'
    elif City == 'CDMX':
        return 'CDMX'
    elif City == 'Cuernavaca':
        return 'Morelos'
    elif City == 'Culiacán':
        return 'Sinaloa'
    elif City == 'Monterrey':
        return 'Nuelo León'
    elif City == 'León':
        return 'Guanajuato'
    else:
        return 'Otro'

# %%
# Apply state assignment function
mthonmerged['Estado'] = mthonmerged['Ciudad'].apply(assign_state)

# %%
mthonmerged.head(200)
# Out:
#        BIB                              Nombre  Edad      Ciudad Talla Genero  \
# 0    101.0  Yineth Estefanía Lizárraga Vázquez  23.0  Hermosillo     M      F
# 1    102.0    Marco Antonio Buenrostro Camargo  32.0  Hermosillo     M      M
# 2    103.0                       Tirso Miranda  44.0  Hermosillo     M      M
# 3    104.0        Carlos Enrique Soto González  54.0  Hermosillo     L      M
# 4    105.0          Eleodoro González González  68.0  Hermosillo     M      M
# ..     ...                                 ...   ...         ...   ...    ...
# 184   49.0            Joel Ernesto Moreno Soto  48.0  Hermosillo     M      M
# 185   50.0     Luis Fernando González Gastelum  38.0  Hermosillo     S      M
# 187   52.0                    Kristina Morales  44.0  Hermosillo     M      F
# 188   53.0                    Humberto Ramírez  44.0  Hermosillo   XXL      M
# 189   54.0     Juan Carlos Fernández (Chileno)  44.0  Hermosillo     M      M
#
#      Maraton  Estado
# ...

# %% [markdown]
# <h2>Data Analysis</h2>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create bins to discretize 'Edad' column
bins = [0, 18, 30, 40, 50, 60, 70, 130]

# Create labels for the bins. These are created according to the marathon rules and categories
labels = ['18-', '18-29', '30-39', '40-49', '50-59', '60-69', '70+']

# Apply labels and bins to discretize 'Edad' column
mthonmerged['Edad'] = pd.cut(mthonmerged['Edad'], bins=bins, labels=labels, right=False)

# %%
mthonmerged.head(200)
# Out:
#        BIB                              Nombre   Edad      Ciudad Talla  \
# 0    101.0  Yineth Estefanía Lizárraga Vázquez  18-29  Hermosillo     M
# 1    102.0    Marco Antonio Buenrostro Camargo  30-39  Hermosillo     M
# 2    103.0                       Tirso Miranda  40-49  Hermosillo     M
# 3    104.0        Carlos Enrique Soto González  50-59  Hermosillo     L
# 4    105.0          Eleodoro González González  60-69  Hermosillo     M
# ..     ...                                 ...    ...         ...   ...
# 184   49.0            Joel Ernesto Moreno Soto  40-49  Hermosillo     M
# 185   50.0     Luis Fernando González Gastelum  30-39  Hermosillo     S
# 187   52.0                    Kristina Morales  40-49  Hermosillo     M
# 188   53.0                    Humberto Ramírez  40-49  Hermosillo   XXL
# 189   54.0     Juan Carlos Fernández (Chileno)  40-49  Hermosillo     M
#
#     Genero  Maraton  Estado
# 0        F        0  Sonora
# 1        M        0  Sonora
# ...

# %%
mthonmerged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 189 entries, 0 to 189
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   BIB      189 non-null    float64
#  1   Nombre   189 non-null    object
#  2   Edad     189 non-null    category
#  3   Ciudad   189 non-null    object
#  4   Talla    189 non-null    object
#  5   Genero   189 non-null    object
#  6   Maraton  189 non-null    int64
#  7   Estado   189 non-null    object
# dtypes: category(1), float64(1), int64(1), object(5)
# memory usage: 16.4+ KB

# %%
mthonmerged.describe()
# Out:
#               BIB     Maraton
# count  189.000000  189.000000
# mean   130.539683    0.285714
# std     76.849430    0.452954
# min      1.000000    0.000000
# 25%     48.000000    0.000000
# 50%    140.000000    0.000000
# 75%    186.000000    1.000000
# max    322.000000    1.000000

# %% [markdown]
# <h2>Plotting results</h2>
#
# ---

# %%
# Set figure size
plt.figure(figsize=(12, 6))

# Plot combined count plot for marathon distances by gender
plt.subplot(1, 2, 1)
ax1 = sns.countplot(x='Edad', hue='Maraton', data=mthonmerged, palette='viridis')
plt.title('Número de participantes en el maratón por edades')
plt.xlabel('Grupo de Edades')
plt.ylabel('Número de Participantes')
plt.legend(title='Ruta', labels=['21 km', '42 km'])
plt.xticks(rotation=45)

# Add counts on top of the bars for the first subplot
for p in ax1.patches:
    ax1.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

# Plot combined count plot for gender by age group
plt.subplot(1, 2, 2)
ax2 = sns.countplot(x='Edad', hue='Genero', data=mthonmerged, palette='magma')
plt.title('Número de participantes en el maratón por edades')
plt.xlabel('Grupo de Edades')
plt.ylabel('Número de Participantes')
plt.legend(title='Género', labels=['Femenino', 'Masculino'])

# Add counts on top of the bars for the second subplot
for p in ax2.patches:
    ax2.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

# Adjust layout
plt.tight_layout()

# Show plot
plt.xticks(rotation=45)
plt.show()

# %%
mthonmerged['Maraton'].value_counts()
# Out:
# 0    135
# 1     54
# Name: Maraton, dtype: int64

# %%
mthonparticipants = mthonmerged['Maraton'].value_counts()

# In case there is a need to add STAFF members, add another row to the pd series
mthonstaff = pd.Series([25], index=[2])
mthonstaff = mthonparticipants.append(mthonstaff)
# Out:
# <ipython-input-52-3c754a4f419a>:5: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mthonstaff = mthonparticipants.append(mthonstaff)

# %%
mthonstaff
# Out:
# 0    135
# 1     54
# 2     25
# dtype: int64

# %%
# Function to show percentage and number value
def func(pct, valores):
    absolute = int(round(pct / 100. * np.sum(valores)))
    return "{:.1f}%\n({:d})".format(pct, absolute)

myexplode1 = [0, 0, 0.05]
plt.figure(figsize=(8,8))

plt.pie(
    x=mthonstaff,
    labels=['21 km', '42 km', 'Staff'],
    # show percentage with two decimal points
    autopct=lambda pct: func(pct, mthonstaff),
    # increase the size of all text elements
    textprops={'fontsize':14},
    colors=sns.color_palette('Set2'),
    startangle = 90,
    explode = myexplode1
)

# Add Title
plt.title(
    label="Participantes del maratón 2024",
    fontdict={"fontsize":16},
    pad=20
)

plt.show()

# %%
# Calculate number of participants per city
city_counts = mthonmerged['Ciudad'].value_counts()

# Order plot by largest count of participants per city to smallest
city_ordered = city_counts.index.tolist()

# Set figure size
plt.figure(figsize=(12, 8))

# Create the countplot with horizontal bars, utilizando los estados ordenados
ax = sns.countplot(y='Ciudad', data=mthonmerged, palette='viridis', order=city_ordered)

# Add counts on the right side of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_width(), p.get_y() + p.get_height() / 2.),
                ha='center', va='center', fontsize=12, color='black', xytext=(14, 0),
                textcoords='offset points')

plt.title('Número de participantes en el maratón por ciudad')
plt.xlabel('Número de Participantes')
plt.ylabel('Ciudad')

# Adjust layout
plt.tight_layout()

plt.show()
# Out:
# <ipython-input-55-b1d40a0bfef9>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(y='Ciudad', data=mthonmerged, palette='viridis', order=city_ordered)

# %%
# Calculate number of participants per state
state_counts = mthonmerged['Estado'].value_counts()

# Order plot by largest count of participants per state to smallest
state_ordered = state_counts.index.tolist()

# Set figure size
plt.figure(figsize=(12, 8))

# Create the countplot with horizontal bars, utilizando los estados ordenados
ax = sns.countplot(y='Estado', data=mthonmerged, palette='viridis', order=state_ordered)

# Add counts on the right side of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_width(), p.get_y() + p.get_height() / 2.),
                ha='center', va='center', fontsize=12, color='black', xytext=(14, 0),
                textcoords='offset points')

plt.title('Número de participantes en el maratón por estado')
plt.xlabel('Número de Participantes')
plt.ylabel('Estado')

# Adjust layout
plt.tight_layout()

plt.show()
# Out:
# <ipython-input-56-1dc83bef169c>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(y='Estado', data=mthonmerged, palette='viridis', order=state_ordered)

# %%
# Order shirt size from "S" to "XXL"
orden_tallas = ['S', 'M', 'L', 'XL', 'XXL']

# Set figure size
plt.figure(figsize=(12, 6))

# Plot of shirt sizes
ax = sns.countplot(x='Talla', hue='Genero', data=mthonmerged, palette='flare', order=orden_tallas)
plt.title('Tallas solicitadas para las camisetas del evento.')
plt.xlabel('Talla')
plt.ylabel('Número de Participantes')

# Add legend
plt.legend(title='Género', labels = ['Femenino', 'Masculino'])

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=12, color='black', xytext=(0, 5),
                textcoords='offset points')

# Show plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Save dataframe to an excel file
path2save = 'Datos_Preprocesados_Inscripciones_Maratones.xlsx'
mthonmerged.to_excel(path2save, index = False)

# These plots will be recreated using power bi; also, feedback from customer will be analyzed to see how to supply even more insight.
